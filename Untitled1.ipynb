# %%
import os
from glob import glob
import dask
import xarray as xr
#from cmocean import cm
import numpy as np
from netCDF4 import Dataset
from scipy.io import loadmat

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from dask.distributed import Client, LocalCluster
    #
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:42331' processes=16 threads=128, memory=251.08 GiB>

# %%
# the path where (Zach's) LLC4320 data are already stored
LLC_data_folder = '/meddy/yuxlong5/data/data_zarr/'
# the path where the data will be re-stored
out_dir = '/meddy/lwang/data/test/'

ds_KPP = xr.open_zarr(LLC_data_folder+'KPPhbl_total_rechunk.zarr')
print(ds_KPP)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:  (time: 9415, lat: 201, lon: 177)
# Coordinates:
#   * time     (time) float64 75kB 0.0 0.04167 0.08333 0.125 ... 392.2 392.2 392.2
# Dimensions without coordinates: lat, lon
# Data variables:
#     KPPhbl   (time, lat, lon) float32 1GB dask.array<chunksize=(9415, 201, 177), meta=np.ndarray>

# %%
wt = ds_KPP.KPPhbl.window
wt.set()

cutoff_time = 48 # A 48-hour cutoff
dx_time = 1 # Define the sampling period (one hour)
wt.set(n=80, dim='time', cutoff=cutoff_time, dx=dx_time, window='hanning')

mld_filter = wt.convolve(trim=True)
mld_filter = np.real(mld_filter).rename('mld_filter')
mld_filter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 wt = ds_KPP.KPPhbl.window
#       2 wt.set()
#       4 cutoff_time = 48 # A 48-hour cutoff
#
# File ~/anaconda3/envs/swc_env/lib/python3.10/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'DataArray' object has no attribute 'window'

# %%
# %time ds_KPP.to_netcdf(out_dir+'/kpp.nc', mode='w')
# Out:
# CPU times: user 76.2 ms, sys: 47.7 ms, total: 124 ms
# Wall time: 1.75 s
